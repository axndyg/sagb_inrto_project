# %% [markdown]
# <a href="https://colab.research.google.com/github/axndyg/sagb_inrto_project/blob/main/Shots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/events_France.csv')

# %%
display(df)
# Out:
#         eventId           subEventName  \
# 0             8            Simple pass
# 1             8              High pass
# 2             1               Air duel
# 3             1               Air duel
# 4             1  Ground attacking duel
# ...         ...                    ...
# 448922        5  Ball out of the field
# 448923        3               Throw in
# 448924        8              High pass
# 448925        1  Ground attacking duel
# 448926        1  Ground defending duel
#
#                                             tags  playerId  \
# 0                                 [{'id': 1801}]    253784
# 1                                 [{'id': 1801}]     29474
# 2                    [{'id': 703}, {'id': 1801}]    253784
# 3                    [{'id': 701}, {'id': 1802}]     56441
# 4                    [{'id': 702}, {'id': 1801}]    366760
# ...                                          ...       ...
# 448922                                        []         0
# 448923                            [{'id': 1801}]    214710
# 448924                            [{'id': 1801}]     26055
# 448925  [{'id': 503}, {'id': 701}, {'id': 1802}]    101795
# 448926  [{'id': 504}, {'id': 703}, {'id': 1801}]    301013
#
#                                        positions  matchId     eventName  \
# 0       [{'y': 51, 'x': 50}, {'y': 46, 'x': 31}]  2500686          Pass
# 1       [{'y': 46, 'x': 31}, {'y': 74, 'x': 68}]  2500686          Pass
# 2       [{'y': 74, 'x': 68}, {'y': 54, 'x': 72}]  2500686          Duel
# 3       [{'y': 26, 'x': 32}, {'y': 46, 'x': 28}]  2500686          Duel
# 4       [{'y': 54, 'x': 72}, {'y': 55, 'x': 73}]  2500686          Duel
# ...                                          ...      ...           ...
# 448922     [{'y': 0, 'x': 19}, {'y': 0, 'x': 0}]  2500956  Interruption
# 448923   [{'y': 0, 'x': 14}, {'y': 13, 'x': 17}]  2500956     Free Kick
# 448924  [{'y': 13, 'x': 17}, {'y': 11, 'x': 38}]  2500956          Pass
# 448925   [{'y': 11, 'x': 38}, {'y': 5, 'x': 43}]  2500956          Duel
# 448926  [{'y': 89, 'x': 62}, {'y': 95, 'x': 57}]    25009           NaN
#
#         teamId matchPeriod    eventSec  subEventId           id  \
# 0       3799.0          1H    1.935181        85.0  176505119.0
# 1       3799.0          1H    3.599295        83.0  176505121.0
# 2       3799.0          1H    6.827043        10.0  176505122.0
# 3       3772.0          1H    6.985577        10.0  176505017.0
# 4       3799.0          1H    9.511272        11.0  176505124.0
# ...        ...         ...         ...         ...          ...
# 448922  3789.0          2H  514.913940        50.0  232022186.0
# 448923  3789.0          2H  520.203591        36.0  232022187.0
# 448924  3789.0          2H  521.331987        83.0  232022189.0
# 448925  3789.0          2H  524.017001        11.0  232022191.0
# 448926     NaN         NaN         NaN         NaN          NaN
#
#                 tagsList  pos_orig_y  pos_orig_x  pos_dest_y  pos_dest_x
# 0                 [1801]        51.0        50.0        46.0        31.0
# 1                 [1801]        46.0        31.0        74.0        68.0
# 2            [703, 1801]        74.0        68.0        54.0        72.0
# 3            [701, 1802]        26.0        32.0        46.0        28.0
# 4            [702, 1801]        54.0        72.0        55.0        73.0
# ...                  ...         ...         ...         ...         ...
# 448922               NaN        32.0        60.0         5.0        71.0
# 448923            [1801]         5.0        71.0         6.0        65.0
# 448924            [1801]        95.0        29.0        94.0        35.0
# 448925  [503, 701, 1802]        94.0        35.0        99.0        45.0
# 448926               NaN         NaN         NaN         NaN         NaN
#
# [448927 rows x 17 columns]

# %%
df_head = df[['eventId', 'subEventName', 'matchId', 'teamId', 'matchPeriod', 'eventSec']]

# %%
display(df_head)
# Out:
#         eventId           subEventName  matchId  teamId matchPeriod  \
# 0             8            Simple pass  2500686  3799.0          1H
# 1             8              High pass  2500686  3799.0          1H
# 2             1               Air duel  2500686  3799.0          1H
# 3             1               Air duel  2500686  3772.0          1H
# 4             1  Ground attacking duel  2500686  3799.0          1H
# ...         ...                    ...      ...     ...         ...
# 448922        5  Ball out of the field  2500956  3789.0          2H
# 448923        3               Throw in  2500956  3789.0          2H
# 448924        8              High pass  2500956  3789.0          2H
# 448925        1  Ground attacking duel  2500956  3789.0          2H
# 448926        1  Ground defending duel    25009     NaN         NaN
#
#           eventSec
# 0         1.935181
# 1         3.599295
# 2         6.827043
# 3         6.985577
# 4         9.511272
# ...            ...
# 448922  514.913940
# 448923  520.203591
# 448924  521.331987
# 448925  524.017001
# 448926         NaN
#
# [448927 rows x 6 columns]

# %%
if 'matchPeriod' in df_head.columns:
  df_head.loc[df_head['matchPeriod'] == '2H', 'eventSec'] += 2700

else:
  print["no"]

print(df_head)
# Out:
#         eventId           subEventName  matchId  teamId matchPeriod  \
# 0             8            Simple pass  2500686  3799.0          1H
# 1             8              High pass  2500686  3799.0          1H
# 2             1               Air duel  2500686  3799.0          1H
# 3             1               Air duel  2500686  3772.0          1H
# 4             1  Ground attacking duel  2500686  3799.0          1H
# ...         ...                    ...      ...     ...         ...
# 448922        5  Ball out of the field  2500956  3789.0          2H
# 448923        3               Throw in  2500956  3789.0          2H
# 448924        8              High pass  2500956  3789.0          2H
# 448925        1  Ground attacking duel  2500956  3789.0          2H
# 448926        1  Ground defending duel    25009     NaN         NaN
#
#            eventSec
# 0          1.935181
# 1          3.599295
# 2          6.827043
# 3          6.985577
# 4          9.511272
# ...             ...
# 448922  3214.913940
# 448923  3220.203591
# 448924  3221.331987
# 448925  3224.017001
# 448926          NaN
#
# [448927 rows x 6 columns]

# %%
display(df_head)
# Out:
#         eventId           subEventName  matchId  teamId matchPeriod  \
# 0             8            Simple pass  2500686  3799.0          1H
# 1             8              High pass  2500686  3799.0          1H
# 2             1               Air duel  2500686  3799.0          1H
# 3             1               Air duel  2500686  3772.0          1H
# 4             1  Ground attacking duel  2500686  3799.0          1H
# ...         ...                    ...      ...     ...         ...
# 448922        5  Ball out of the field  2500956  3789.0          2H
# 448923        3               Throw in  2500956  3789.0          2H
# 448924        8              High pass  2500956  3789.0          2H
# 448925        1  Ground attacking duel  2500956  3789.0          2H
# 448926        1  Ground defending duel    25009     NaN         NaN
#
#            eventSec
# 0          1.935181
# 1          3.599295
# 2          6.827043
# 3          6.985577
# 4          9.511272
# ...             ...
# 448922  3214.913940
# 448923  3220.203591
# 448924  3221.331987
# 448925  3224.017001
# 448926          NaN
#
# [448927 rows x 6 columns]

# %%
df_head2 = df_head[['eventId', 'subEventName', 'matchId', 'teamId', 'eventSec']]

# %%
display(df_head2)
# Out:
#         eventId           subEventName  matchId  teamId     eventSec
# 0             8            Simple pass  2500686  3799.0     1.935181
# 1             8              High pass  2500686  3799.0     3.599295
# 2             1               Air duel  2500686  3799.0     6.827043
# 3             1               Air duel  2500686  3772.0     6.985577
# 4             1  Ground attacking duel  2500686  3799.0     9.511272
# ...         ...                    ...      ...     ...          ...
# 448922        5  Ball out of the field  2500956  3789.0  3214.913940
# 448923        3               Throw in  2500956  3789.0  3220.203591
# 448924        8              High pass  2500956  3789.0  3221.331987
# 448925        1  Ground attacking duel  2500956  3789.0  3224.017001
# 448926        1  Ground defending duel    25009     NaN          NaN
#
# [448927 rows x 5 columns]

# %%
df_head2 = df_head2[df_head2['subEventName'] == 'Shot']

print(df_head2)
# Out:
#         eventId subEventName  matchId  teamId     eventSec
# 213          10         Shot  2500686  3799.0   605.975493
# 302          10         Shot  2500686  3772.0   859.236394
# 498          10         Shot  2500686  3772.0  1568.104834
# 577          10         Shot  2500686  3772.0  1800.852078
# 629          10         Shot  2500686  3799.0  2009.537139
# ...         ...          ...      ...     ...          ...
# 448692       10         Shot  2500956  3774.0  2377.907095
# 448709       10         Shot  2500956  3774.0  2405.772369
# 448792       10         Shot  2500956  3774.0  2691.241465
# 448828       10         Shot  2500956  3774.0  2819.463295
# 448904       10         Shot  2500956  3789.0  3053.700364
#
# [5795 rows x 5 columns]
